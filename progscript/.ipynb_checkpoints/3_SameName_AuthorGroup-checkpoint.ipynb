# %%
# load the paper metadata
import sys
import io
import os

Dataset = "pubmed"

fileDir = "../Data/"+Dataset+"/canopies/"
listfiles = os.listdir(fileDir)

LabeledRecords_original = []

for file in listfiles:
    if not file.startswith('.'):
        with open(fileDir+file, 'r', encoding = 'utf8') as f:
            counter = 0
            for line in f:
                read_data = line.split("\t")
                # get ride of bad formated lines
                if(len(read_data)==13):
                    paper_detail = {"paperID": read_data[0], "authorID":read_data[1],
                                    "author_position":read_data[2], "total_author": read_data[3],
                                    "author_name": read_data[4], "co_authors": read_data[5], 
                                    "department": read_data[6], "vendor": read_data[7], 
                                    "mesh": read_data[8], "keywords": read_data[9], 
                                    "publish_year": read_data[10], "citation graph": read_data[11]}
                    LabeledRecords_original.append(paper_detail)
                    counter+=1
            print("Author Name: ",file, " contains ", counter, " records.")
        f.close()
print("Total records:",len(LabeledRecords_original), "records")
# Out:
# Author Name:  canopy_j_read  contains  1092  records.
# Author Name:  canopy_f_esteves  contains  154  records.
# Author Name:  canopy_c_miller  contains  6816  records.
# Author Name:  canopy_r_jha  contains  373  records.
# Author Name:  canopy_a_lowe  contains  874  records.
# Author Name:  canopy_a_vega  contains  579  records.
# Author Name:  canopy_k_smith  contains  8854  records.
# Author Name:  canopy_j_gordon  contains  3772  records.
# Author Name:  canopy_s_liao  contains  2377  records.
# Author Name:  canopy_j_qian  contains  3469  records.
# Author Name:  canopy_s_bernardi  contains  251  records.
# Author Name:  canopy_t_hill  contains  1195  records.
# Author Name:  canopy_s_schindler  contains  228  records.
# Author Name:  canopy_j_williams  contains  13942  records.
# Author Name:  canopy_s_jacobson  contains  1563  records.
# Author Name:  canopy_e_andrade  contains  350  records.
# Author Name:  canopy_t_santos  contains  632  records.
# Author Name:  canopy_k_kim  contains  30688  records.
# Author Name:  canopy_d_ricci  contains  400  records.
# Author Name:  canopy_s_cameron  contains  801  records.
# Author Name:  canopy_t_wright  contains  1892  records.
# Author Name:  canopy_r_cunha  contains  652  records.
# Author Name:  canopy_s_fuchs  contains  1327  records.
# Author Name:  canopy_m_nawaz  contains  294  records.
# Author Name:  canopy_k_harris  contains  2152  records.
# Author Name:  canopy_r_daniel  contains  1234  records.
# Author Name:  canopy_k_xu  contains  4032  records.
# Author Name:  canopy_s_antunes  contains  146  records.
# Author Name:  canopy_k_cho  contains  6055  records.
# Author Name:  canopy_j_sanderson  contains  815  records.
# Author Name:  canopy_s_uddin  contains  326  records.
# Author Name:  canopy_a_batista  contains  470  records.
# Author Name:  canopy_h_pereira  contains  673  records.
# Author Name:  canopy_a_patel  contains  6372  records.
# Author Name:  canopy_r_graham  contains  1776  records.
# Author Name:  canopy_a_nilsson  contains  1309  records.
# Author Name:  canopy_m_soto  contains  673  records.
# Author Name:  canopy_g_guidi  contains  602  records.
# Author Name:  canopy_e_andersson  contains  665  records.
# Author Name:  canopy_s_reid  contains  1570  records.
# Author Name:  canopy_a_maleki  contains  148  records.
# Author Name:  canopy_j_moon  contains  3625  records.
# Author Name:  canopy_t_abe  contains  6312  records.
# Author Name:  canopy_x_fu  contains  4787  records.
# Author Name:  canopy_f_ortega  contains  828  records.
# Author Name:  canopy_r_morris  contains  3808  records.
# Author Name:  canopy_w_fang  contains  2537  records.
# Author Name:  canopy_m_amaral  contains  496  records.
# Author Name:  canopy_h_song  contains  8326  records.
# Author Name:  canopy_h_dai  contains  6  records.
# Author Name:  canopy_y_nakajima  contains  2618  records.
# Author Name:  canopy_t_warner  contains  773  records.
# Author Name:  canopy_s_saha  contains  2567  records.
# Author Name:  canopy_j_fernandez  contains  1894  records.
# Author Name:  canopy_m_pan  contains  1445  records.
# Author Name:  canopy_a_simon  contains  2862  records.
# Author Name:  canopy_r_freitas  contains  523  records.
# Author Name:  canopy_c_yun  contains  1094  records.
# Author Name:  canopy_j_huang  contains  20436  records.
# Author Name:  canopy_p_santos  contains  1015  records.
# Author Name:  canopy_n_young  contains  1707  records.
# Author Name:  canopy_d_ross  contains  3320  records.
# Author Name:  canopy_q_wang  contains  24335  records.
# Author Name:  canopy_c_cardoso  contains  718  records.
# Author Name:  canopy_j_matthews  contains  2316  records.
# Author Name:  canopy_g_lee  contains  7102  records.
# Author Name:  canopy_m_salem  contains  815  records.
# Author Name:  canopy_h_lai  contains  2117  records.
# Author Name:  canopy_r_harris  contains  5954  records.
# Author Name:  canopy_c_vaughan  contains  597  records.
# Author Name:  canopy_e_thompson  contains  2748  records.
# Author Name:  canopy_r_gomes  contains  716  records.
# Author Name:  canopy_r_bennett  contains  1747  records.
# Author Name:  canopy_m_collins  contains  3568  records.
# Author Name:  canopy_m_cowley  contains  354  records.
# Author Name:  canopy_p_teixeira  contains  634  records.
# Author Name:  canopy_c_cox  contains  2524  records.
# Author Name:  canopy_s_hsu  contains  3546  records.
# Author Name:  canopy_f_williams  contains  1079  records.
# Author Name:  canopy_d_parsons  contains  689  records.
# Author Name:  canopy_a_choudhury  contains  688  records.
# Author Name:  canopy_c_richter  contains  1005  records.
# Author Name:  canopy_m_hossain  contains  2713  records.
# Author Name:  canopy_v_alves  contains  470  records.
# Author Name:  canopy_j_becker  contains  3569  records.
# Author Name:  canopy_m_soares  contains  2042  records.
# Author Name:  canopy_j_yi  contains  2555  records.
# Author Name:  canopy_s_khan  contains  7379  records.
# Author Name:  canopy_a_rao  contains  3590  records.
# Author Name:  canopy_d_cameron  contains  1990  records.
# Author Name:  canopy_c_morgan  contains  1958  records.
# Author Name:  canopy_h_cui  contains  2701  records.
# Author Name:  canopy_p_zhang  contains  10392  records.
# Author Name:  canopy_j_fernandes  contains  1456  records.
# Author Name:  canopy_a_jain  contains  4361  records.
# Author Name:  canopy_d_zhang  contains  15453  records.
# Author Name:  canopy_b_huang  contains  4587  records.
# Author Name:  canopy_m_chong  contains  517  records.
# Author Name:  canopy_m_cerqueira  contains  355  records.
# Author Name:  canopy_p_yang  contains  6908  records.
# Author Name:  canopy_j_marques  contains  708  records.
# Author Name:  canopy_n_ali  contains  1408  records.
# Author Name:  canopy_h_ng  contains  1468  records.
# Author Name:  canopy_m_viana  contains  573  records.
# Author Name:  canopy_t_inoue  contains  8256  records.
# Author Name:  canopy_b_meyer  contains  2232  records.
# Author Name:  canopy_c_liao  contains  3193  records.
# Author Name:  canopy_k_wheeler  contains  546  records.
# Author Name:  canopy_m_rizzo  contains  1260  records.
# Author Name:  canopy_y_shi  contains  11850  records.
# Author Name:  canopy_c_luo  contains  3007  records.
# Author Name:  canopy_j_arthur  contains  704  records.
# Author Name:  canopy_m_ansari  contains  1325  records.
# Author Name:  canopy_g_anderson  contains  4493  records.
# Author Name:  canopy_m_hidalgo  contains  754  records.
# Author Name:  canopy_k_jacobsen  contains  487  records.
# Author Name:  canopy_s_kelly  contains  2493  records.
# Author Name:  canopy_s_james  contains  2161  records.
# Author Name:  canopy_p_persson  contains  619  records.
# Author Name:  canopy_y_tanaka  contains  10217  records.
# Author Name:  canopy_c_gao  contains  3943  records.
# Author Name:  canopy_w_jung  contains  1738  records.
# Author Name:  canopy_s_lewis  contains  4534  records.
# Author Name:  canopy_w_han  contains  3355  records.
# Author Name:  canopy_m_shah  contains  3290  records.
# Author Name:  canopy_c_arango  contains  322  records.
# Author Name:  canopy_r_young  contains  5254  records.
# Author Name:  canopy_r_coleman  contains  2732  records.
# Author Name:  canopy_b_kang  contains  2262  records.
# Author Name:  canopy_s_carter  contains  1937  records.
# Author Name:  canopy_c_thomas  contains  5681  records.
# Author Name:  canopy_m_gutierrez  contains  895  records.
# Author Name:  canopy_s_moon  contains  3266  records.
# Author Name:  canopy_r_pereira  contains  1768  records.
# Author Name:  canopy_a_nielsen  contains  1373  records.
# Author Name:  canopy_j_conde  contains  385  records.
# Author Name:  canopy_k_wright  contains  1861  records.
# Author Name:  canopy_m_parker  contains  3242  records.
# Author Name:  canopy_h_huang  contains  16175  records.
# Author Name:  canopy_j_terry  contains  467  records.
# Author Name:  canopy_y_xu  contains  24016  records.
# Author Name:  canopy_a_melo  contains  746  records.
# Author Name:  canopy_r_doyle  contains  683  records.
# Author Name:  canopy_m_bernardo  contains  629  records.
# Author Name:  canopy_j_soares  contains  1461  records.
# Author Name:  canopy_j_richard  contains  1560  records.
# Author Name:  canopy_p_robinson  contains  3192  records.
# Author Name:  canopy_c_zou  contains  1006  records.
# Author Name:  canopy_s_rana  contains  1192  records.
# Author Name:  canopy_a_nunes  contains  560  records.
# Author Name:  canopy_s_jeong  contains  4424  records.
# Author Name:  canopy_b_olsen  contains  966  records.
# Author Name:  canopy_m_reilly  contains  1168  records.
# Author Name:  canopy_d_nguyen  contains  2809  records.
# Author Name:  canopy_r_santos  contains  2652  records.
# Author Name:  canopy_f_ferreira  contains  1182  records.
# Author Name:  canopy_y_ng  contains  1123  records.
# Author Name:  canopy_j_madsen  contains  1375  records.
# Author Name:  canopy_d_collins  contains  2085  records.
# Author Name:  canopy_l_davies  contains  930  records.
# Author Name:  canopy_m_mora  contains  783  records.
# Author Name:  canopy_a_fontana  contains  1112  records.
# Author Name:  canopy_r_chen  contains  9528  records.
# Author Name:  canopy_s_krause  contains  629  records.
# Author Name:  canopy_t_smith  contains  9157  records.
# Author Name:  canopy_a_biswas  contains  1215  records.
# Author Name:  canopy_j_day  contains  1639  records.
# Author Name:  canopy_d_truong  contains  300  records.
# Author Name:  canopy_s_pan  contains  2851  records.
# Author Name:  canopy_a_andrade  contains  954  records.
# Author Name:  canopy_t_oliveira  contains  553  records.
# Author Name:  canopy_n_romano  contains  205  records.
# Author Name:  canopy_t_hara  contains  3208  records.
# Author Name:  canopy_t_wong  contains  4135  records.
# Author Name:  canopy_s_ross  contains  2939  records.
# Author Name:  canopy_d_richardson  contains  2765  records.
# Author Name:  canopy_j_moraes  contains  293  records.
# Author Name:  canopy_e_moreno  contains  921  records.
# Author Name:  canopy_r_little  contains  937  records.
# Author Name:  canopy_t_kobayashi  contains  10320  records.
# Author Name:  canopy_a_lin  contains  2937  records.
# Author Name:  canopy_a_miranda  contains  1048  records.
# Author Name:  canopy_h_vogel  contains  1824  records.
# Author Name:  canopy_m_campos  contains  1467  records.
# Author Name:  canopy_d_stewart  contains  3443  records.
# Author Name:  canopy_j_abrantes  contains  104  records.
# Author Name:  canopy_j_arroyo  contains  586  records.
# Author Name:  canopy_a_giuliani  contains  704  records.
# Author Name:  canopy_f_campos  contains  516  records.
# Author Name:  canopy_a_mitchell  contains  2598  records.
# Author Name:  canopy_c_murray  contains  2068  records.
# Author Name:  canopy_m_grant  contains  1826  records.
# Author Name:  canopy_d_scott  contains  4740  records.
# Author Name:  canopy_s_mohan  contains  1330  records.
# Author Name:  canopy_n_wong  contains  1372  records.
# Author Name:  canopy_k_anderson  contains  5411  records.
# Author Name:  canopy_m_king  contains  4124  records.
# Author Name:  canopy_a_srivastava  contains  3636  records.
# Author Name:  canopy_m_scholz  contains  945  records.
# Author Name:  canopy_y_ju  contains  1087  records.
# Author Name:  canopy_d_stanley  contains  426  records.
# Author Name:  canopy_c_nogueira  contains  752  records.
# Author Name:  canopy_j_cooper  contains  5699  records.
# Author Name:  canopy_k_lau  contains  1707  records.
# Author Name:  canopy_s_hussein  contains  380  records.
# Author Name:  canopy_z_luo  contains  3649  records.
# Author Name:  canopy_c_pimentel  contains  104  records.
# Author Name:  canopy_s_ito  contains  6237  records.
# Author Name:  canopy_f_zhang  contains  12848  records.
# Author Name:  canopy_s_chapman  contains  1681  records.
# Author Name:  canopy_j_rosa  contains  970  records.
# Author Name:  canopy_y_yin  contains  4337  records.
# Author Name:  canopy_p_tavares  contains  251  records.
# Author Name:  canopy_a_palma  contains  619  records.
# Author Name:  canopy_e_shaw  contains  1014  records.
# Author Name:  canopy_m_cameron  contains  778  records.
# Author Name:  canopy_a_reid  contains  1421  records.
# Author Name:  canopy_d_gil  contains  283  records.
# Author Name:  canopy_s_morgan  contains  1776  records.
# Author Name:  canopy_p_ross  contains  1396  records.
# Author Name:  canopy_l_simon  contains  1246  records.
# Author Name:  canopy_k_thomas  contains  3030  records.
# Author Name:  canopy_l_torres  contains  813  records.
# Author Name:  canopy_p_ding  contains  614  records.
# Author Name:  canopy_g_morris  contains  1845  records.
# Author Name:  canopy_s_andrews  contains  880  records.
# Author Name:  canopy_b_yan  contains  2441  records.
# Author Name:  canopy_r_hu  contains  2251  records.
# Author Name:  canopy_j_braun  contains  2349  records.
# Author Name:  canopy_c_he  contains  4036  records.
# Author Name:  canopy_w_lu  contains  6106  records.
# Author Name:  canopy_r_radhakrishnan  contains  378  records.
# Author Name:  canopy_k_saito  contains  6305  records.
# Author Name:  canopy_y_wang  contains  99069  records.
# Author Name:  canopy_j_gao  contains  9448  records.
# Author Name:  canopy_d_fernandes  contains  507  records.
# Author Name:  canopy_c_silva  contains  3060  records.
# Author Name:  canopy_t_fitzgerald  contains  612  records.
# Author Name:  canopy_j_mitchell  contains  6216  records.
# Author Name:  canopy_a_gomes  contains  2000  records.
# Author Name:  canopy_t_weber  contains  1689  records.
# Author Name:  canopy_j_shim  contains  2611  records.
# Author Name:  canopy_k_kang  contains  3383  records.
# Author Name:  canopy_i_ferreira  contains  771  records.
# Author Name:  canopy_y_jia  contains  2750  records.
# Author Name:  canopy_p_gaspar  contains  231  records.
# Author Name:  canopy_r_o'connor  contains  1387  records.
# Author Name:  canopy_k_larsen  contains  903  records.
# Author Name:  canopy_s_das  contains  7762  records.
# Author Name:  canopy_f_rodriguez  contains  825  records.
# Author Name:  canopy_w_peng  contains  2018  records.
# Author Name:  canopy_c_torres  contains  1264  records.
# Author Name:  canopy_s_rossi  contains  1747  records.
# Author Name:  canopy_s_alavi  contains  380  records.
# Author Name:  canopy_r_marques  contains  431  records.
# Author Name:  canopy_m_wheeler  contains  1251  records.
# Author Name:  canopy_l_rasmussen  contains  1459  records.
# Author Name:  canopy_m_saad  contains  4  records.
# Author Name:  canopy_j_carr  contains  1916  records.
# Author Name:  canopy_j_fraser  contains  1720  records.
# Author Name:  canopy_s_woo  contains  2768  records.
# Author Name:  canopy_s_bartlett  contains  847  records.
# Author Name:  canopy_m_lucas  contains  1324  records.
# Author Name:  canopy_w_lee  contains  17085  records.
# Author Name:  canopy_j_cheng  contains  10033  records.
# Author Name:  canopy_g_lewis  contains  2737  records.
# Author Name:  canopy_j_albert  contains  1339  records.
# Author Name:  canopy_k_goh  contains  1116  records.
# Author Name:  canopy_n_harris  contains  1379  records.
# Author Name:  canopy_s_hill  contains  2684  records.
# Author Name:  canopy_p_pathak  contains  263  records.
# Author Name:  canopy_h_zeng  contains  2842  records.
# Author Name:  canopy_h_liu  contains  34440  records.
# Author Name:  canopy_s_bae  contains  3073  records.
# Author Name:  canopy_s_fernandes  contains  629  records.
# Author Name:  canopy_a_miller  contains  7378  records.
# Author Name:  canopy_a_eklund  contains  538  records.
# Author Name:  canopy_r_moore  contains  6086  records.
# Author Name:  canopy_m_thomsen  contains  866  records.
# Author Name:  canopy_l_ng  contains  1318  records.
# Author Name:  canopy_a_phillips  contains  2901  records.
# Author Name:  canopy_y_ye  contains  3801  records.
# Author Name:  canopy_m_guerreiro  contains  269  records.
# Author Name:  canopy_g_alves  contains  724  records.
# Author Name:  canopy_m_mohammed  contains  6  records.
# Author Name:  canopy_s_mohammadi  contains  498  records.
# Author Name:  canopy_c_chao  contains  1737  records.
# Author Name:  canopy_s_teixeira  contains  510  records.
# Author Name:  canopy_l_almeida  contains  688  records.
# Author Name:  canopy_y_tseng  contains  1695  records.
# Author Name:  canopy_a_ferro  contains  639  records.
# Author Name:  canopy_d_he  contains  2429  records.
# Author Name:  canopy_k_ko  contains  1705  records.
# Author Name:  canopy_t_mori  contains  6940  records.
# Author Name:  canopy_p_lima  contains  297  records.
# Author Name:  canopy_d_ferguson  contains  1627  records.
# Author Name:  canopy_h_moreira  contains  200  records.
# Author Name:  canopy_s_yi  contains  1911  records.
# Author Name:  canopy_q_liu  contains  14643  records.
# Author Name:  canopy_m_ibrahim  contains  2094  records.
# Author Name:  canopy_s_collins  contains  2671  records.
# Author Name:  canopy_d_franco  contains  692  records.
# Author Name:  canopy_h_brown  contains  2612  records.
# Author Name:  canopy_s_martins  contains  739  records.
# Author Name:  canopy_m_ruiz  contains  1782  records.
# Author Name:  canopy_a_levy  contains  2249  records.
# Author Name:  canopy_j_murray  contains  5274  records.
# Author Name:  canopy_y_hou  contains  4268  records.
# Author Name:  canopy_m_sahin  contains  983  records.
# Author Name:  canopy_c_feng  contains  2556  records.
# Author Name:  canopy_j_coutinho  contains  375  records.
# Author Name:  canopy_s_huber  contains  1071  records.
# Author Name:  canopy_a_rocha  contains  1052  records.
# Author Name:  canopy_a_white  contains  4492  records.
# Author Name:  canopy_j_scott  contains  7258  records.
# Author Name:  canopy_s_hosseini  contains  1198  records.
# Author Name:  canopy_d_vieira  contains  497  records.
# Author Name:  canopy_j_kang  contains  9701  records.
# Author Name:  canopy_j_jensen  contains  4483  records.
# Author Name:  canopy_k_lai  contains  2112  records.
# Author Name:  canopy_j_gonzalez  contains  2005  records.
# Author Name:  canopy_m_zakaria  contains  341  records.
# Author Name:  canopy_c_campos  contains  689  records.
# Author Name:  canopy_a_gad  contains  249  records.
# Author Name:  canopy_y_zhao  contains  28188  records.
# Author Name:  canopy_s_hussain  contains  2533  records.
# Author Name:  canopy_k_scott  contains  1536  records.
# Author Name:  canopy_a_martinez  contains  2772  records.
# Author Name:  canopy_r_luz  contains  72  records.
# Author Name:  canopy_p_tran  contains  760  records.
# Author Name:  canopy_e_romero  contains  677  records.
# Author Name:  canopy_j_stevens  contains  3210  records.
# Author Name:  canopy_l_you  contains  1028  records.
# Author Name:  canopy_p_stevenson  contains  527  records.
# Author Name:  canopy_t_kang  contains  1934  records.
# Author Name:  canopy_s_mohanty  contains  1246  records.
# Author Name:  canopy_m_amorim  contains  463  records.
# Author Name:  canopy_y_kamiya  contains  659  records.
# Author Name:  canopy_w_he  contains  4014  records.
# Author Name:  canopy_t_kato  contains  8436  records.
# Author Name:  canopy_a_ward  contains  2076  records.
# Author Name:  canopy_j_chen  contains  36800  records.
# Author Name:  canopy_m_tseng  contains  761  records.
# Author Name:  canopy_c_henderson  contains  1380  records.
# Author Name:  canopy_j_mcdonald  contains  3679  records.
# Author Name:  canopy_m_ismail  contains  1271  records.
# Author Name:  canopy_x_xu  contains  20625  records.
# Author Name:  canopy_f_liu  contains  13200  records.
# Author Name:  canopy_a_rego  contains  248  records.
# Author Name:  canopy_s_hammad  contains  139  records.
# Author Name:  canopy_k_johansson  contains  840  records.
# Author Name:  canopy_m_barreto  contains  607  records.
# Author Name:  canopy_j_moore  contains  8527  records.
# Author Name:  canopy_a_gray  contains  1945  records.
# Author Name:  canopy_v_martins  contains  396  records.
# Author Name:  canopy_t_zhou  contains  3342  records.
# Author Name:  canopy_s_howell  contains  1446  records.
# Author Name:  canopy_m_larsson  contains  945  records.
# Author Name:  canopy_s_morris  contains  2625  records.
# Author Name:  canopy_s_biswas  contains  1939  records.
# Author Name:  canopy_s_patel  contains  7203  records.
# Author Name:  canopy_m_white  contains  5152  records.
# Author Name:  canopy_s_sherman  contains  1944  records.
# Author Name:  canopy_j_dai  contains  3958  records.
# Author Name:  canopy_m_fischer  contains  3736  records.
# Author Name:  canopy_y_zeng  contains  5278  records.
# Author Name:  canopy_j_turner  contains  4442  records.
# Author Name:  canopy_c_cai  contains  1763  records.
# Author Name:  canopy_f_pereira  contains  1052  records.
# Author Name:  canopy_a_vitale  contains  637  records.
# Author Name:  canopy_q_yang  contains  7877  records.
# Author Name:  canopy_d_xue  contains  701  records.
# Author Name:  canopy_m_sadeghi  contains  861  records.
# Author Name:  canopy_h_chang  contains  11103  records.
# Author Name:  canopy_a_lombardi  contains  988  records.
# Author Name:  canopy_c_correia  contains  341  records.
# Author Name:  canopy_j_you  contains  2406  records.
# Author Name:  canopy_c_lopez  contains  822  records.
# Author Name:  canopy_y_oh  contains  3097  records.
# Author Name:  canopy_s_yoon  contains  5920  records.
# Author Name:  canopy_a_lima  contains  1497  records.
# Author Name:  canopy_h_singh  contains  3639  records.
# Author Name:  canopy_s_scott  contains  2244  records.
# Author Name:  canopy_z_he  contains  5615  records.
# Author Name:  canopy_s_mukherjee  contains  3326  records.
# Author Name:  canopy_j_yue  contains  1139  records.
# Author Name:  canopy_f_dias  contains  687  records.
# Author Name:  canopy_r_walker  contains  5020  records.
# Author Name:  canopy_l_campos  contains  780  records.
# Author Name:  canopy_m_iqbal  contains  1394  records.
# Author Name:  canopy_s_lim  contains  7961  records.
# Author Name:  canopy_p_li  contains  12345  records.
# Author Name:  canopy_f_andrade  contains  415  records.
# Author Name:  canopy_c_schmitt  contains  1427  records.
# Author Name:  canopy_t_tan  contains  2690  records.
# Author Name:  canopy_h_gomes  contains  245  records.
# Author Name:  canopy_m_matos  contains  621  records.
# Author Name:  canopy_k_ryan  contains  1524  records.
# Author Name:  canopy_w_zheng  contains  5249  records.
# Author Name:  canopy_j_franco  contains  731  records.
# Author Name:  canopy_l_walker  contains  2328  records.
# Author Name:  canopy_a_gordon  contains  2716  records.
# Author Name:  canopy_z_yin  contains  2684  records.
# Author Name:  canopy_c_gu  contains  1636  records.
# Author Name:  canopy_a_soto  contains  505  records.
# Author Name:  canopy_h_hsieh  contains  1103  records.
# Author Name:  canopy_m_crespo  contains  692  records.
# Author Name:  canopy_s_phillips  contains  2738  records.
# Author Name:  canopy_r_rodrigues  contains  1187  records.
# Author Name:  canopy_a_mansour  contains  761  records.
# Author Name:  canopy_a_lau  contains  1259  records.
# Author Name:  canopy_j_berg  contains  1547  records.
# Author Name:  canopy_l_wilson  contains  3094  records.
# Author Name:  canopy_c_park  contains  12026  records.
# Author Name:  canopy_r_thomas  contains  5329  records.
# Author Name:  canopy_j_fonseca  contains  717  records.
# Author Name:  canopy_s_henderson  contains  1142  records.
# Author Name:  canopy_m_coelho  contains  624  records.
# Author Name:  canopy_j_pearson  contains  2419  records.
# Author Name:  canopy_z_xie  contains  4141  records.
# Author Name:  canopy_m_wright  contains  2757  records.
# Author Name:  canopy_j_song  contains  12257  records.
# Author Name:  canopy_k_becker  contains  2658  records.
# Author Name:  canopy_r_sinha  contains  1972  records.
# Author Name:  canopy_c_turner  contains  2364  records.
# Author Name:  canopy_y_su  contains  6651  records.
# Author Name:  canopy_a_popov  contains  1657  records.
# Author Name:  canopy_w_liao  contains  2472  records.
# Author Name:  canopy_j_zhong  contains  3097  records.
# Author Name:  canopy_a_wheeler  contains  713  records.
# Author Name:  canopy_m_walsh  contains  3194  records.
# Author Name:  canopy_r_figueiredo  contains  261  records.
# Author Name:  canopy_y_lin  contains  21372  records.
# Author Name:  canopy_k_sato  contains  10614  records.
# Author Name:  canopy_f_ahmed  contains  1086  records.
# Author Name:  canopy_y_watanabe  contains  8649  records.
# Author Name:  canopy_k_singh  contains  5142  records.
# Author Name:  canopy_j_mcevoy  contains  553  records.
# Author Name:  canopy_g_singh  contains  4269  records.
# Author Name:  canopy_e_ford  contains  969  records.
# Author Name:  canopy_s_chou  contains  2060  records.
# Author Name:  canopy_s_hughes  contains  2455  records.
# Author Name:  canopy_m_thomas  contains  6938  records.
# Author Name:  canopy_j_liang  contains  5886  records.
# Author Name:  canopy_t_wu  contains  8431  records.
# Author Name:  canopy_b_ahmed  contains  447  records.
# Author Name:  canopy_m_takahashi  contains  11563  records.
# Author Name:  canopy_i_lee  contains  5807  records.
# Author Name:  canopy_a_figueiredo  contains  707  records.
# Author Name:  canopy_s_clark  contains  3509  records.
# Author Name:  canopy_a_schmid  contains  1110  records.
# Author Name:  canopy_k_cheung  contains  1579  records.
# Author Name:  canopy_s_ma  contains  5098  records.
# Author Name:  canopy_m_marino  contains  1039  records.
# Author Name:  canopy_a_kirby  contains  559  records.
# Author Name:  canopy_d_roberts  contains  4779  records.
# Author Name:  canopy_b_thompson  contains  2182  records.
# Author Name:  canopy_j_blanco  contains  1755  records.
# Author Name:  canopy_x_cai  contains  4063  records.
# Author Name:  canopy_r_menezes  contains  551  records.
# Author Name:  canopy_s_tsang  contains  789  records.
# Author Name:  canopy_c_king  contains  2579  records.
# Author Name:  canopy_h_kobayashi  contains  6967  records.
# Author Name:  canopy_k_yang  contains  6522  records.
# Author Name:  canopy_b_zheng  contains  2268  records.
# Author Name:  canopy_f_xu  contains  5249  records.
# Author Name:  canopy_r_day  contains  2011  records.
# Author Name:  canopy_j_young  contains  7730  records.
# Author Name:  canopy_c_black  contains  1538  records.
# Author Name:  canopy_s_joseph  contains  1392  records.
# Author Name:  canopy_z_fan  contains  3062  records.
# Author Name:  canopy_j_matos  contains  312  records.
# Author Name:  canopy_l_santos  contains  1797  records.
# Author Name:  canopy_g_taylor  contains  4271  records.
# Author Name:  canopy_x_yang  contains  25148  records.
# Author Name:  canopy_s_bianchi  contains  1036  records.
# Author Name:  canopy_a_morales  contains  1388  records.
# Author Name:  canopy_p_wong  contains  3318  records.
# Author Name:  canopy_a_cooper  contains  2629  records.
# Author Name:  canopy_j_nguyen  contains  1416  records.
# Author Name:  canopy_t_lang  contains  1036  records.
# Author Name:  canopy_s_russo  contains  927  records.
# Author Name:  canopy_r_arora  contains  1834  records.
# Author Name:  canopy_c_porter  contains  1344  records.
# Author Name:  canopy_m_moore  contains  5202  records.
# Author Name:  canopy_c_johnson  contains  8345  records.
# Author Name:  canopy_e_henry  contains  707  records.
# Author Name:  canopy_x_xie  contains  5958  records.
# Author Name:  canopy_x_jin  contains  4535  records.
# Author Name:  canopy_s_singh  contains  15487  records.
# Author Name:  canopy_m_reid  contains  2325  records.
# Author Name:  canopy_m_wallace  contains  2429  records.
# Author Name:  canopy_y_zhang  contains  83970  records.
# Author Name:  canopy_m_young  contains  4412  records.
# Author Name:  canopy_s_saraf  contains  320  records.
# Author Name:  canopy_r_pinto  contains  1305  records.
# Author Name:  canopy_m_brito  contains  525  records.
# Author Name:  canopy_s_goel  contains  779  records.
# Author Name:  canopy_y_park  contains  14838  records.
# Author Name:  canopy_p_melo  contains  247  records.
# Author Name:  canopy_c_lemos  contains  191  records.
# Author Name:  canopy_b_liu  contains  14184  records.
# Author Name:  canopy_k_turner  contains  1106  records.
# Author Name:  canopy_r_rao  contains  2485  records.
# Author Name:  canopy_b_barker  contains  368  records.
# Author Name:  canopy_a_wright  contains  3922  records.
# Author Name:  canopy_z_ma  contains  5121  records.
# Author Name:  canopy_s_bose  contains  1475  records.
# Author Name:  canopy_j_dyer  contains  760  records.
# Author Name:  canopy_f_blanco  contains  738  records.
# Author Name:  canopy_s_ferreira  contains  1438  records.
# Author Name:  canopy_j_ren  contains  4834  records.
# Author Name:  canopy_j_muller  contains  1734  records.
# Author Name:  canopy_h_tanaka  contains  10600  records.
# Author Name:  canopy_j_pierce  contains  1861  records.
# Author Name:  canopy_j_guerrero  contains  795  records.
# Author Name:  canopy_r_coelho  contains  474  records.
# Author Name:  canopy_a_masi  contains  418  records.
# Author Name:  canopy_b_jackson  contains  1734  records.
# Author Name:  canopy_a_jha  contains  1129  records.
# Author Name:  canopy_m_mosquera  contains  173  records.
# Author Name:  canopy_a_silva  contains  5097  records.
# Author Name:  canopy_m_guerra  contains  979  records.
# Author Name:  canopy_h_suzuki  contains  10898  records.
# Author Name:  canopy_m_cohen  contains  9952  records.
# Author Name:  canopy_m_kobayashi  contains  9020  records.
# Author Name:  canopy_s_wright  contains  3138  records.
# Author Name:  canopy_a_mills  contains  1129  records.
# Author Name:  canopy_c_west  contains  2316  records.
# Author Name:  canopy_a_marino  contains  884  records.
# Author Name:  canopy_r_jiang  contains  2081  records.
# Author Name:  canopy_t_becker  contains  1566  records.
# Author Name:  canopy_s_pedersen  contains  1765  records.
# Author Name:  canopy_a_ali  contains  3919  records.
# Author Name:  canopy_k_jones  contains  5532  records.
# Author Name:  canopy_m_becker  contains  2483  records.
# Author Name:  canopy_c_marshall  contains  1492  records.
# Author Name:  canopy_s_rafiq  contains  89  records.
# Author Name:  canopy_h_liang  contains  4628  records.
# Author Name:  canopy_c_davis  contains  4984  records.
# Author Name:  canopy_e_hall  contains  1915  records.
# Author Name:  canopy_g_volpe  contains  255  records.
# Author Name:  canopy_r_lewis  contains  5052  records.
# Author Name:  canopy_c_rodriguez  contains  1329  records.
# Author Name:  canopy_p_hall  contains  1964  records.
# Author Name:  canopy_r_srivastava  contains  1947  records.
# Author Name:  canopy_a_macedo  contains  611  records.
# Author Name:  canopy_m_schultz  contains  1350  records.
# Author Name:  canopy_s_jacobs  contains  1440  records.
# Author Name:  canopy_c_hong  contains  3260  records.
# Author Name:  canopy_r_mohan  contains  939  records.
# Author Name:  canopy_r_hill  contains  4244  records.
# Author Name:  canopy_q_shen  contains  2341  records.
# Author Name:  canopy_l_schmidt  contains  1459  records.
# Author Name:  canopy_s_qin  contains  1733  records.
# Author Name:  canopy_a_fabbri  contains  592  records.
# Author Name:  canopy_l_robinson  contains  1654  records.
# Author Name:  canopy_r_gross  contains  2489  records.
# Author Name:  canopy_j_ahn  contains  5437  records.
# Author Name:  canopy_j_john  contains  970  records.
# Author Name:  canopy_d_lloyd  contains  1714  records.
# Author Name:  canopy_a_mohammadi  contains  577  records.
# Author Name:  canopy_d_dean  contains  1559  records.
# Author Name:  canopy_s_chang  contains  12705  records.
# Author Name:  canopy_m_conte  contains  1103  records.
# Author Name:  canopy_i_wilson  contains  2179  records.
# Author Name:  canopy_h_yoo  contains  2747  records.
# Author Name:  canopy_d_das  contains  2065  records.
# Author Name:  canopy_d_carr  contains  1472  records.
# Author Name:  canopy_s_sahu  contains  804  records.
# Author Name:  canopy_m_tsai  contains  3988  records.
# Author Name:  canopy_m_vitale  contains  783  records.
# Author Name:  canopy_r_castro  contains  955  records.
# Author Name:  canopy_a_hassan  contains  1971  records.
# Author Name:  canopy_w_martin  contains  2772  records.
# Author Name:  canopy_a_krishnan  contains  873  records.
# Author Name:  canopy_l_tavares  contains  265  records.
# Author Name:  canopy_t_murakami  contains  3952  records.
# Author Name:  canopy_x_xiao  contains  4254  records.
# Author Name:  canopy_j_davies  contains  5079  records.
# Author Name:  canopy_a_schmidt  contains  3890  records.
# Author Name:  canopy_j_nieto  contains  695  records.
# Author Name:  canopy_s_hasan  contains  971  records.
# Author Name:  canopy_m_teixeira  contains  2384  records.
# Author Name:  canopy_j_koh  contains  1702  records.
# Author Name:  canopy_m_amin  contains  1599  records.
# Author Name:  canopy_h_cho  contains  6370  records.
# Author Name:  canopy_s_lam  contains  2318  records.
# Author Name:  canopy_t_tran  contains  2718  records.
# Author Name:  canopy_c_su  contains  3943  records.
# Author Name:  canopy_s_george  contains  3020  records.
# Author Name:  canopy_j_hong  contains  7386  records.
# Author Name:  canopy_p_baptista  contains  229  records.
# Author Name:  canopy_p_thompson  contains  4433  records.
# Author Name:  canopy_a_castro  contains  2337  records.
# Author Name:  canopy_j_zhang  contains  62321  records.
# Author Name:  canopy_j_rodrigues  contains  1620  records.
# Author Name:  canopy_s_watson  contains  2078  records.
# Author Name:  canopy_c_barros  contains  387  records.
# Author Name:  canopy_f_cardoso  contains  681  records.
# Author Name:  canopy_m_pinto  contains  1468  records.
# Author Name:  canopy_j_cuevas  contains  626  records.
# Author Name:  canopy_j_chang  contains  11257  records.
# Author Name:  canopy_a_dias  contains  1068  records.
# Author Name:  canopy_j_choi  contains  17431  records.
# Author Name:  canopy_m_ahmed  contains  3848  records.
# Author Name:  canopy_j_jo  contains  786  records.
# Author Name:  canopy_n_dawson  contains  371  records.
# Author Name:  canopy_j_barbosa  contains  1003  records.
# Author Name:  canopy_e_o'connor  contains  395  records.
# Author Name:  canopy_c_zheng  contains  3318  records.
# Author Name:  canopy_r_hall  contains  4282  records.
# Author Name:  canopy_d_hwang  contains  2106  records.
# Author Name:  canopy_c_shen  contains  4060  records.
# Author Name:  canopy_v_lopes  contains  278  records.
# Author Name:  canopy_m_quintana  contains  444  records.
# Author Name:  canopy_j_nunes  contains  550  records.
# Author Name:  canopy_z_nagy  contains  1265  records.
# Author Name:  canopy_e_brown  contains  5047  records.
# Author Name:  canopy_j_nielsen  contains  5138  records.
# Author Name:  canopy_w_choi  contains  3234  records.
# Author Name:  canopy_d_tavares  contains  210  records.
# Author Name:  canopy_l_alves  contains  646  records.
# Author Name:  canopy_s_chan  contains  5920  records.
# Author Name:  canopy_b_ferreira  contains  296  records.
# Author Name:  canopy_r_neves  contains  482  records.
# Author Name:  canopy_m_cardoso  contains  1175  records.
# Author Name:  canopy_c_shao  contains  1307  records.
# Author Name:  canopy_h_yeo  contains  270  records.
# Author Name:  canopy_m_goodman  contains  2632  records.
# Author Name:  canopy_r_dias  contains  758  records.
# Author Name:  canopy_s_sengupta  contains  1743  records.
# Author Name:  canopy_y_jung  contains  4204  records.
# Author Name:  canopy_c_franco  contains  628  records.
# Author Name:  canopy_v_wong  contains  1547  records.
# Author Name:  canopy_j_feng  contains  6291  records.
# Author Name:  canopy_s_murugesan  contains  144  records.
# Author Name:  canopy_j_camacho  contains  421  records.
# Author Name:  canopy_b_moreno  contains  271  records.
# Author Name:  canopy_j_andersen  contains  3010  records.
# Author Name:  canopy_j_bell  contains  4282  records.
# Author Name:  canopy_m_bull  contains  350  records.
# Author Name:  canopy_s_gandhi  contains  880  records.
# Author Name:  canopy_c_yang  contains  16156  records.
# Author Name:  canopy_s_paul  contains  3182  records.
# Author Name:  canopy_l_roberts  contains  2641  records.
# Author Name:  canopy_s_keating  contains  362  records.
# Author Name:  canopy_a_bennett  contains  2034  records.
# Author Name:  canopy_a_aggarwal  contains  1890  records.
# Author Name:  canopy_i_moura  contains  377  records.
# Author Name:  canopy_d_teixeira  contains  235  records.
# Author Name:  canopy_c_klein  contains  2422  records.
# Author Name:  canopy_m_andersson  contains  1809  records.
# Author Name:  canopy_h_shi  contains  5436  records.
# Author Name:  canopy_d_howard  contains  1350  records.
# Author Name:  canopy_j_thomsen  contains  976  records.
# Author Name:  canopy_v_gupta  contains  3958  records.
# Author Name:  canopy_j_manning  contains  1137  records.
# Author Name:  canopy_r_wood  contains  3250  records.
# Author Name:  canopy_y_ding  contains  7336  records.
# Author Name:  canopy_j_rasmussen  contains  1116  records.
# Author Name:  canopy_n_lee  contains  4686  records.
# Author Name:  canopy_a_oliveira  contains  2631  records.
# Author Name:  canopy_h_yin  contains  4007  records.
# Author Name:  canopy_k_brown  contains  5585  records.
# Author Name:  canopy_s_hong  contains  11806  records.
# Author Name:  canopy_l_zhou  contains  11739  records.
# Author Name:  canopy_h_jiang  contains  11073  records.
# Author Name:  canopy_a_lewis  contains  2798  records.
# Author Name:  canopy_c_meyer  contains  3698  records.
# Author Name:  canopy_a_islam  contains  891  records.
# Author Name:  canopy_k_fujita  contains  3585  records.
# Author Name:  canopy_a_khan  contains  8730  records.
# Author Name:  canopy_a_kim  contains  3355  records.
# Author Name:  canopy_m_martinez  contains  2160  records.
# Author Name:  canopy_m_aslam  contains  711  records.
# Author Name:  canopy_j_wolf  contains  2757  records.
# Author Name:  canopy_s_agrawal  contains  2096  records.
# Author Name:  canopy_a_othman  contains  327  records.
# Author Name:  canopy_k_evans  contains  1362  records.
# Author Name:  canopy_k_yoo  contains  1841  records.
# Author Name:  canopy_d_turner  contains  2496  records.
# Author Name:  canopy_j_king  contains  4715  records.
# Author Name:  canopy_b_shen  contains  3166  records.
# Author Name:  canopy_s_mishra  contains  3157  records.
# Author Name:  canopy_c_o'connor  contains  1454  records.
# Author Name:  canopy_e_svensson  contains  408  records.
# Author Name:  canopy_o_ahmed  contains  339  records.
# Author Name:  canopy_t_shimada  contains  2476  records.
# Author Name:  canopy_a_watts  contains  794  records.
# Author Name:  canopy_b_oliveira  contains  352  records.
# Author Name:  canopy_t_ito  contains  7896  records.
# Author Name:  canopy_t_jackson  contains  1442  records.
# Author Name:  canopy_m_romero  contains  1407  records.
# Author Name:  canopy_j_west  contains  2962  records.
# Author Name:  canopy_c_guo  contains  6  records.
# Author Name:  canopy_m_hansen  contains  3161  records.
# Author Name:  canopy_x_qian  contains  2376  records.
# Author Name:  canopy_m_wagner  contains  4161  records.
# Author Name:  canopy_d_campos  contains  374  records.
# Author Name:  canopy_r_clark  contains  5660  records.
# Author Name:  canopy_b_zhou  contains  4851  records.
# Author Name:  canopy_x_yan  contains  5594  records.
# Author Name:  canopy_x_li  contains  60268  records.
# Author Name:  canopy_j_burton  contains  1310  records.
# Author Name:  canopy_x_feng  contains  6210  records.
# Author Name:  canopy_w_hussein  contains  81  records.
# Author Name:  canopy_c_santos  contains  2181  records.
# Author Name:  canopy_j_figueroa  contains  873  records.
# Author Name:  canopy_w_cui  contains  1781  records.
# Author Name:  canopy_d_moreira  contains  574  records.
# Author Name:  canopy_m_graham  contains  2114  records.
# Author Name:  canopy_g_dias  contains  224  records.
# Author Name:  canopy_h_yoshida  contains  6206  records.
# Author Name:  canopy_m_branco  contains  151  records.
# Author Name:  canopy_k_chong  contains  729  records.
# Author Name:  canopy_j_kumar  contains  1143  records.
# Author Name:  canopy_a_shenoy  contains  288  records.
# Author Name:  canopy_h_yang  contains  22602  records.
# Author Name:  canopy_m_magnusson  contains  707  records.
# Author Name:  canopy_m_foster  contains  1199  records.
# Author Name:  canopy_j_lynch  contains  3315  records.
# Author Name:  canopy_j_boyle  contains  1502  records.
# Author Name:  canopy_r_turner  contains  3549  records.
# Author Name:  canopy_s_brooks  contains  1643  records.
# Author Name:  canopy_p_moreira  contains  563  records.
# Author Name:  canopy_s_mukhopadhyay  contains  1509  records.
# Author Name:  canopy_a_hudson  contains  1023  records.
# Author Name:  canopy_d_thomas  contains  7794  records.
# Author Name:  canopy_w_smith  contains  5824  records.
# Author Name:  canopy_l_martin  contains  4829  records.
# Author Name:  canopy_c_garcia  contains  1889  records.
# Author Name:  canopy_g_huang  contains  5418  records.
# Author Name:  canopy_j_huber  contains  1468  records.
# Author Name:  canopy_j_qin  contains  3291  records.
# Author Name:  canopy_t_ho  contains  1673  records.
# Author Name:  canopy_c_keller  contains  1239  records.
# Author Name:  canopy_m_maia  contains  470  records.
# Author Name:  canopy_p_bates  contains  569  records.
# Author Name:  canopy_s_chow  contains  1296  records.
# Author Name:  canopy_m_simon  contains  4034  records.
# Author Name:  canopy_s_kar  contains  1196  records.
# Author Name:  canopy_d_vlachos  contains  127  records.
# Author Name:  canopy_e_law  contains  277  records.
# Author Name:  canopy_m_ribeiro  contains  1860  records.
# Author Name:  canopy_r_king  contains  3463  records.
# Author Name:  canopy_o_nielsen  contains  1250  records.
# Author Name:  canopy_j_moreno  contains  1946  records.
# Author Name:  canopy_f_yu  contains  3644  records.
# Author Name:  canopy_f_esposito  contains  735  records.
# Author Name:  canopy_p_miranda  contains  419  records.
# Author Name:  canopy_s_yang  contains  20987  records.
# Author Name:  canopy_d_huang  contains  5581  records.
# Author Name:  canopy_h_kuo  contains  2018  records.
# Author Name:  canopy_a_santoro  contains  1695  records.
# Author Name:  canopy_q_lu  contains  3953  records.
# Author Name:  canopy_s_kumar  contains  14694  records.
# Author Name:  canopy_s_rocha  contains  572  records.
# Author Name:  canopy_t_han  contains  2016  records.
# Author Name:  canopy_m_sandberg  contains  536  records.
# Author Name:  canopy_j_marshall  contains  5110  records.
# Author Name:  canopy_f_bianchi  contains  1285  records.
# Author Name:  canopy_c_liu  contains  23985  records.
# Author Name:  canopy_d_sanders  contains  2032  records.
# Author Name:  canopy_r_brito  contains  265  records.
# Author Name:  canopy_w_chang  contains  6273  records.
# Author Name:  canopy_a_murray  contains  2342  records.
# Author Name:  canopy_b_cao  contains  1358  records.
# Author Name:  canopy_k_sohn  contains  445  records.
# Author Name:  canopy_m_bennett  contains  3737  records.
# Author Name:  canopy_a_sharma  contains  9536  records.
# Author Name:  canopy_z_wei  contains  2993  records.
# Author Name:  canopy_x_gu  contains  4183  records.
# Author Name:  canopy_l_yang  contains  14903  records.
# Author Name:  canopy_h_hassan  contains  905  records.
# Author Name:  canopy_f_chen  contains  10311  records.
# Author Name:  canopy_g_rossi  contains  3933  records.
# Author Name:  canopy_s_patil  contains  2428  records.
# Author Name:  canopy_m_kelly  contains  3740  records.
# Author Name:  canopy_m_cheung  contains  1186  records.
# Author Name:  canopy_j_weaver  contains  1687  records.
# Author Name:  canopy_c_chien  contains  1828  records.
# Author Name:  canopy_s_yun  contains  2191  records.
# Author Name:  canopy_s_jung  contains  6769  records.
# Author Name:  canopy_e_gomes  contains  538  records.
# Author Name:  canopy_t_yamaguchi  contains  6417  records.
# Author Name:  canopy_p_oliveira  contains  1301  records.
# Author Name:  canopy_r_torres  contains  1062  records.
# Author Name:  canopy_a_esteves  contains  207  records.
# Author Name:  canopy_l_stevens  contains  1018  records.
# Author Name:  canopy_a_chang  contains  3659  records.
# Author Name:  canopy_l_song  contains  4956  records.
# Author Name:  canopy_j_delgado  contains  1157  records.
# Author Name:  canopy_p_jensen  contains  2654  records.
# Author Name:  canopy_t_allen  contains  1808  records.
# Author Name:  canopy_j_sullivan  contains  3384  records.
# Author Name:  canopy_s_rogers  contains  2307  records.
# Author Name:  canopy_h_yoon  contains  3833  records.
# Author Name:  canopy_a_young  contains  4726  records.
# Author Name:  canopy_m_richardson  contains  2417  records.
# Author Name:  canopy_c_ryan  contains  2267  records.
# Author Name:  canopy_l_jensen  contains  2191  records.
# Author Name:  canopy_h_ferreira  contains  504  records.
# Author Name:  canopy_a_mahmoud  contains  902  records.
# Author Name:  canopy_y_liao  contains  3865  records.
# Author Name:  canopy_m_svensson  contains  710  records.
# Author Name:  canopy_p_tsai  contains  1468  records.
# Author Name:  canopy_r_berry  contains  1187  records.
# Author Name:  canopy_j_kwok  contains  341  records.
# Author Name:  canopy_m_schneider  contains  4559  records.
# Author Name:  canopy_k_wood  contains  1639  records.
# Author Name:  canopy_c_viegas  contains  224  records.
# Author Name:  canopy_r_d'souza  contains  457  records.
# Author Name:  canopy_s_shim  contains  1055  records.
# Author Name:  canopy_j_herrero  contains  528  records.
# Author Name:  canopy_m_acosta  contains  436  records.
# Author Name:  canopy_a_chan  contains  5162  records.
# Author Name:  canopy_p_kelly  contains  2979  records.
# Author Name:  canopy_j_weiner  contains  1148  records.
# Author Name:  canopy_b_yu  contains  4705  records.
# Author Name:  canopy_s_lucas  contains  1272  records.
# Author Name:  canopy_e_davis  contains  2232  records.
# Author Name:  canopy_z_yu  contains  7720  records.
# Author Name:  canopy_c_pan  contains  3324  records.
# Author Name:  canopy_x_cao  contains  5656  records.
# Author Name:  canopy_j_yoo  contains  3682  records.
# Author Name:  canopy_l_wong  contains  2734  records.
# Author Name:  canopy_h_chen  contains  37802  records.
# Author Name:  canopy_c_huang  contains  20565  records.
# Author Name:  canopy_s_chong  contains  1418  records.
# Author Name:  canopy_z_wu  contains  12687  records.
# Author Name:  canopy_m_swamy  contains  320  records.
# Author Name:  canopy_k_nomura  contains  1697  records.
# Author Name:  canopy_m_wu  contains  11488  records.
# Author Name:  canopy_e_lee  contains  12718  records.
# Author Name:  canopy_j_weber  contains  3751  records.
# Author Name:  canopy_c_fox  contains  1971  records.
# Author Name:  canopy_s_thompson  contains  3225  records.
# Author Name:  canopy_b_choi  contains  4661  records.
# Author Name:  canopy_j_schwartz  contains  5385  records.
# Author Name:  canopy_a_brooks  contains  1676  records.
# Author Name:  canopy_l_rocha  contains  678  records.
# Author Name:  canopy_s_fleming  contains  981  records.
# Author Name:  canopy_w_tsai  contains  2136  records.
# Author Name:  canopy_m_rodriguez  contains  3051  records.
# Author Name:  canopy_r_miranda  contains  832  records.
# Author Name:  canopy_j_richardson  contains  3808  records.
# Author Name:  canopy_a_chin  contains  612  records.
# Author Name:  canopy_h_madsen  contains  500  records.
# Author Name:  canopy_m_ferguson  contains  2020  records.
# Author Name:  canopy_s_mitra  contains  2112  records.
# Author Name:  canopy_v_pinto  contains  456  records.
# Author Name:  canopy_m_field  contains  1224  records.
# Author Name:  canopy_c_jones  contains  7539  records.
# Author Name:  canopy_k_hong  contains  2488  records.
# Author Name:  canopy_t_williams  contains  4396  records.
# Author Name:  canopy_j_xavier  contains  243  records.
# Author Name:  canopy_b_bhushan  contains  341  records.
# Author Name:  canopy_r_ellis  contains  2148  records.
# Author Name:  canopy_v_saini  contains  291  records.
# Author Name:  canopy_a_ellis  contains  1180  records.
# Author Name:  canopy_f_reis  contains  570  records.
# Author Name:  canopy_j_gray  contains  4370  records.
# Author Name:  canopy_r_hughes  contains  3244  records.
# Author Name:  canopy_a_green  contains  4423  records.
# Author Name:  canopy_c_reis  contains  514  records.
# Author Name:  canopy_f_scott  contains  747  records.
# Author Name:  canopy_l_han  contains  4655  records.
# Author Name:  canopy_c_martins  contains  1325  records.
# Author Name:  canopy_r_schneider  contains  2787  records.
# Author Name:  canopy_j_regan  contains  793  records.
# Author Name:  canopy_s_brennan  contains  688  records.
# Author Name:  canopy_v_patel  contains  2916  records.
# Author Name:  canopy_d_johnston  contains  2562  records.
# Author Name:  canopy_r_gupta  contains  8874  records.
# Author Name:  canopy_s_reddy  contains  3075  records.
# Author Name:  canopy_y_yao  contains  5706  records.
# Author Name:  canopy_a_huang  contains  2468  records.
# Author Name:  canopy_d_ghosh  contains  1278  records.
# Author Name:  canopy_r_morgan  contains  2738  records.
# Author Name:  canopy_q_li  contains  21859  records.
# Author Name:  canopy_w_wang  contains  32113  records.
# Author Name:  canopy_r_ross  contains  3259  records.
# Author Name:  canopy_k_yamamoto  contains  11181  records.
# Author Name:  canopy_j_silva  contains  4286  records.
# Author Name:  canopy_m_pellegrini  contains  844  records.
# Author Name:  canopy_s_kwon  contains  4114  records.
# Author Name:  canopy_m_correa  contains  563  records.
# Author Name:  canopy_a_pal  contains  1060  records.
# Author Name:  canopy_v_costa  contains  710  records.
# Author Name:  canopy_j_allen  contains  6278  records.
# Author Name:  canopy_y_dong  contains  5914  records.
# Author Name:  canopy_m_fitzgerald  contains  1983  records.
# Author Name:  canopy_m_ferreira  contains  3128  records.
# Author Name:  canopy_m_roberts  contains  4181  records.
# Author Name:  canopy_y_lim  contains  3783  records.
# Author Name:  canopy_g_miller  contains  4938  records.
# Author Name:  canopy_x_kong  contains  3122  records.
# Author Name:  canopy_w_cao  contains  3112  records.
# Author Name:  canopy_c_ma  contains  6140  records.
# Author Name:  canopy_j_chin  contains  1419  records.
# Author Name:  canopy_h_kwon  contains  3693  records.
# Author Name:  canopy_s_gao  contains  5318  records.
# Author Name:  canopy_f_tian  contains  1637  records.
# Author Name:  canopy_f_martins  contains  535  records.
# Author Name:  canopy_s_wolf  contains  2544  records.
# Author Name:  canopy_m_goldman  contains  2753  records.
# Author Name:  canopy_d_tang  contains  2427  records.
# Author Name:  canopy_m_adams  contains  3999  records.
# Author Name:  canopy_t_singh  contains  1889  records.
# Author Name:  canopy_m_thompson  contains  4718  records.
# Author Name:  canopy_s_garcia  contains  1181  records.
# Author Name:  canopy_e_wang  contains  4451  records.
# Author Name:  canopy_c_scott  contains  2825  records.
# Author Name:  canopy_m_mukherjee  contains  534  records.
# Author Name:  canopy_j_schroeder  contains  1479  records.
# Author Name:  canopy_a_mayer  contains  1388  records.
# Author Name:  canopy_e_wright  contains  2114  records.
# Author Name:  canopy_c_moreno  contains  1136  records.
# Author Name:  canopy_a_moura  contains  464  records.
# Author Name:  canopy_j_lopez  contains  1734  records.
# Author Name:  canopy_a_logan  contains  646  records.
# Author Name:  canopy_l_williams  contains  4435  records.
# Author Name:  canopy_h_young  contains  1840  records.
# Author Name:  canopy_a_vincent  contains  1808  records.
# Author Name:  canopy_a_monteiro  contains  829  records.
# Author Name:  canopy_d_park  contains  5271  records.
# Author Name:  canopy_d_gao  contains  2094  records.
# Author Name:  canopy_d_quinn  contains  630  records.
# Author Name:  canopy_n_dias  contains  245  records.
# Author Name:  canopy_k_fisher  contains  966  records.
# Author Name:  canopy_m_schubert  contains  1161  records.
# Author Name:  canopy_j_peters  contains  4551  records.
# Author Name:  canopy_e_zimmermann  contains  503  records.
# Author Name:  canopy_c_zhang  contains  23345  records.
# Author Name:  canopy_h_shin  contains  6514  records.
# Author Name:  canopy_r_reis  contains  1400  records.
# Author Name:  canopy_z_ren  contains  2173  records.
# Author Name:  canopy_m_kumar  contains  4312  records.
# Author Name:  canopy_j_wong  contains  5859  records.
# Author Name:  canopy_s_turner  contains  2467  records.
# Author Name:  canopy_y_yuan  contains  6663  records.
# Author Name:  canopy_l_liu  contains  25271  records.
# Author Name:  canopy_a_fonseca  contains  775  records.
# Author Name:  canopy_r_francis  contains  745  records.
# Author Name:  canopy_l_castro  contains  926  records.
# Author Name:  canopy_k_zhou  contains  1806  records.
# Author Name:  canopy_m_macdonald  contains  1565  records.
# Author Name:  canopy_h_guan  contains  1315  records.
# Author Name:  canopy_t_miller  contains  3983  records.
# Author Name:  canopy_m_kang  contains  4386  records.
# Author Name:  canopy_z_shi  contains  4180  records.
# Author Name:  canopy_t_johnson  contains  4403  records.
# Author Name:  canopy_m_ferretti  contains  326  records.
# Author Name:  canopy_b_peng  contains  1455  records.
# Author Name:  canopy_m_fernandes  contains  1604  records.
# Author Name:  canopy_l_cui  contains  3240  records.
# Author Name:  canopy_s_monteiro  contains  426  records.
# Author Name:  canopy_m_hsieh  contains  2234  records.
# Author Name:  canopy_c_nelson  contains  3246  records.
# Author Name:  canopy_j_barnett  contains  1136  records.
# Author Name:  canopy_j_tian  contains  4509  records.
# Author Name:  canopy_f_costa  contains  1909  records.
# Author Name:  canopy_a_mccarthy  contains  819  records.
# Author Name:  canopy_y_cheng  contains  10790  records.
# Author Name:  canopy_i_hwang  contains  2080  records.
# Author Name:  canopy_y_liu  contains  67940  records.
# Author Name:  canopy_m_engel  contains  741  records.
# Author Name:  canopy_w_shi  contains  4255  records.
# Author Name:  canopy_d_matthews  contains  1566  records.
# Author Name:  canopy_j_christensen  contains  2675  records.
# Author Name:  canopy_j_sampaio  contains  402  records.
# Author Name:  canopy_j_dias  contains  1167  records.
# Author Name:  canopy_p_nunes  contains  294  records.
# Author Name:  canopy_c_bauer  contains  1663  records.
# Author Name:  canopy_r_patel  contains  4665  records.
# Author Name:  canopy_a_das  contains  4526  records.
# Author Name:  canopy_c_becker  contains  2946  records.
# Author Name:  canopy_k_zhu  contains  1840  records.
# Author Name:  canopy_a_machado  contains  1399  records.
# Author Name:  canopy_j_alexander  contains  4527  records.
# Author Name:  canopy_j_schneider  contains  4620  records.
# Author Name:  canopy_g_russo  contains  1539  records.
# Author Name:  canopy_j_carvalho  contains  1441  records.
# Author Name:  canopy_y_nishikawa  contains  955  records.
# Author Name:  canopy_j_ward  contains  4423  records.
# Author Name:  canopy_m_singh  contains  6986  records.
# Author Name:  canopy_a_bhattacharyya  contains  897  records.
# Author Name:  canopy_e_morris  contains  1307  records.
# Author Name:  canopy_m_lewis  contains  5272  records.
# Author Name:  canopy_v_fernandes  contains  302  records.
# Author Name:  canopy_m_pinheiro  contains  626  records.
# Author Name:  canopy_j_petersen  contains  2299  records.
# Author Name:  canopy_k_shimizu  contains  5235  records.
# Author Name:  canopy_p_shaw  contains  2046  records.
# Author Name:  canopy_g_coppola  contains  725  records.
# Author Name:  canopy_a_sinclair  contains  1033  records.
# Author Name:  canopy_y_pan  contains  6573  records.
# Author Name:  canopy_m_ramos  contains  1667  records.
# Author Name:  canopy_j_tsai  contains  2930  records.
# Author Name:  canopy_f_dai  contains  590  records.
# Author Name:  canopy_t_martin  contains  3223  records.
# Author Name:  canopy_t_o'brien  contains  2348  records.
# Author Name:  canopy_s_may  contains  843  records.
# Author Name:  canopy_z_cai  contains  2973  records.
# Author Name:  canopy_a_pereira  contains  3097  records.
# Author Name:  canopy_d_patel  contains  3330  records.
# Author Name:  canopy_a_james  contains  2676  records.
# Author Name:  canopy_c_cao  contains  2241  records.
# Author Name:  canopy_c_brown  contains  7967  records.
# Author Name:  canopy_y_liang  contains  7880  records.
# Author Name:  canopy_y_fan  contains  6249  records.
# Author Name:  canopy_j_simon  contains  3932  records.
# Author Name:  canopy_m_jeong  contains  1558  records.
# Author Name:  canopy_j_barrett  contains  3216  records.
# Author Name:  canopy_d_elliott  contains  1559  records.
# Author Name:  canopy_p_antunes  contains  153  records.
# Author Name:  canopy_x_yuan  contains  2670  records.
# Author Name:  canopy_t_kim  contains  15095  records.
# Author Name:  canopy_a_cruz  contains  1583  records.
# Author Name:  canopy_a_mora  contains  457  records.
# Author Name:  canopy_j_walker  contains  6292  records.
# Author Name:  canopy_j_alves  contains  723  records.
# Author Name:  canopy_j_seo  contains  4841  records.
# Author Name:  canopy_y_tang  contains  9986  records.
# Author Name:  canopy_a_norman  contains  1596  records.
# Author Name:  canopy_s_tanaka  contains  9037  records.
# Author Name:  canopy_c_wen  contains  1329  records.
# Author Name:  canopy_c_myers  contains  1395  records.
# Author Name:  canopy_v_santos  contains  647  records.
# Author Name:  canopy_j_brown  contains  14339  records.
# Author Name:  canopy_b_pandey  contains  339  records.
# Author Name:  canopy_d_morgan  contains  3530  records.
# Author Name:  canopy_r_smith  contains  18694  records.
# Author Name:  canopy_a_guerrero  contains  792  records.
# Author Name:  canopy_a_grant  contains  2025  records.
# Author Name:  canopy_v_kumar  contains  5881  records.
# Author Name:  canopy_p_shah  contains  3858  records.
# Author Name:  canopy_t_yu  contains  3422  records.
# Author Name:  canopy_r_singh  contains  9800  records.
# Author Name:  canopy_c_baker  contains  2639  records.
# Author Name:  canopy_a_cattaneo  contains  692  records.
# Author Name:  canopy_a_ferrari  contains  2028  records.
# Author Name:  canopy_a_murphy  contains  2201  records.
# Author Name:  canopy_f_hong  contains  679  records.
# Author Name:  canopy_m_ferrari  contains  3092  records.
# Author Name:  canopy_j_paredes  contains  275  records.
# Author Name:  canopy_z_zhao  contains  9686  records.
# Author Name:  canopy_j_cao  contains  5948  records.
# Author Name:  canopy_d_kuo  contains  395  records.
# Author Name:  canopy_a_andersen  contains  1787  records.
# Author Name:  canopy_m_longo  contains  698  records.
# Author Name:  canopy_h_chiang  contains  1375  records.
# Author Name:  canopy_m_o'brien  contains  2239  records.
# Author Name:  canopy_s_ray  contains  2637  records.
# Author Name:  canopy_a_cheng  contains  3192  records.
# Author Name:  canopy_j_savage  contains  785  records.
# Author Name:  canopy_p_matthews  contains  1041  records.
# Author Name:  canopy_i_carvalho  contains  195  records.
# Author Name:  canopy_j_parsons  contains  2157  records.
# Author Name:  canopy_s_oliveira  contains  1341  records.
# Author Name:  canopy_h_kang  contains  8176  records.
# Author Name:  canopy_s_vogt  contains  588  records.
# Author Name:  canopy_d_garcia  contains  970  records.
# Author Name:  canopy_w_xie  contains  3111  records.
# Author Name:  canopy_m_cruz  contains  1414  records.
# Author Name:  canopy_w_xu  contains  7253  records.
# Author Name:  canopy_k_roy  contains  992  records.
# Author Name:  canopy_b_white  contains  1922  records.
# Author Name:  canopy_p_graham  contains  760  records.
# Author Name:  canopy_d_rubin  contains  1436  records.
# Author Name:  canopy_b_ryan  contains  447  records.
# Author Name:  canopy_j_kim  contains  75975  records.
# Author Name:  canopy_a_duarte  contains  1271  records.
# Author Name:  canopy_a_correia  contains  523  records.
# Author Name:  canopy_a_reynolds  contains  1041  records.
# Author Name:  canopy_g_qin  contains  1129  records.
# Author Name:  canopy_m_tang  contains  3720  records.
# Author Name:  canopy_a_baranov  contains  425  records.
# Author Name:  canopy_r_gray  contains  3075  records.
# Author Name:  canopy_r_nunes  contains  467  records.
# Author Name:  canopy_s_huang  contains  15360  records.
# Author Name:  canopy_c_reid  contains  1282  records.
# Author Name:  canopy_h_lu  contains  8819  records.
# Author Name:  canopy_j_cordeiro  contains  310  records.
# Author Name:  canopy_c_yu  contains  10583  records.
# Author Name:  canopy_d_simpson  contains  2113  records.
# Author Name:  canopy_c_pereira  contains  1789  records.
# Author Name:  canopy_h_wang  contains  55763  records.
# Author Name:  canopy_a_tan  contains  2359  records.
# Author Name:  canopy_m_aguilar  contains  932  records.
# Author Name:  canopy_a_bianchi  contains  1546  records.
# Author Name:  canopy_p_rossi  contains  1980  records.
# Author Name:  canopy_y_yang  contains  36729  records.
# Author Name:  canopy_s_hsieh  contains  1462  records.
# Author Name:  canopy_c_baptista  contains  134  records.
# Author Name:  canopy_d_kavanagh  contains  394  records.
# Author Name:  canopy_l_wang  contains  53293  records.
# Author Name:  canopy_m_pinho  contains  229  records.
# Author Name:  canopy_m_bergman  contains  597  records.
# Author Name:  canopy_j_castro  contains  1712  records.
# Author Name:  canopy_n_hall  contains  959  records.
# Author Name:  canopy_d_schneider  contains  2334  records.
# Author Name:  canopy_n_kumar  contains  4012  records.
# Author Name:  canopy_i_martins  contains  470  records.
# Author Name:  canopy_j_qiu  contains  3641  records.
# Author Name:  canopy_m_antunes  contains  566  records.
# Author Name:  canopy_m_andersen  contains  2592  records.
# Author Name:  canopy_l_xiao  contains  3431  records.
# Author Name:  canopy_m_hartmann  contains  1304  records.
# Author Name:  canopy_k_nielsen  contains  1988  records.
# Author Name:  canopy_m_sousa  contains  1056  records.
# Author Name:  canopy_a_coelho  contains  721  records.
# Author Name:  canopy_r_sanz  contains  203  records.
# Author Name:  canopy_m_ferrara  contains  608  records.
# Author Name:  canopy_c_hui  contains  865  records.
# Author Name:  canopy_l_bruno  contains  292  records.
# Author Name:  canopy_s_nielsen  contains  2834  records.
# Author Name:  canopy_b_russell  contains  791  records.
# Author Name:  canopy_y_wu  contains  28478  records.
# Author Name:  canopy_j_soto  contains  819  records.
# Author Name:  canopy_r_mckay  contains  894  records.
# Author Name:  canopy_d_sharma  contains  2371  records.
# Author Name:  canopy_a_wilson  contains  5839  records.
# Author Name:  canopy_f_marini  contains  374  records.
# Author Name:  canopy_h_tsai  contains  2818  records.
# Author Name:  canopy_s_o'brien  contains  2813  records.
# Author Name:  canopy_c_webb  contains  1146  records.
# Author Name:  canopy_c_adams  contains  2283  records.
# Author Name:  canopy_c_peng  contains  3508  records.
# Author Name:  canopy_k_kobayashi  contains  8703  records.
# Author Name:  canopy_s_larsen  contains  1613  records.
# Total labeled records: 4163770 records

# %%
from collections import Counter
# count number of publication based on only name
Record_NameCounter = Counter([records["author_name"] for records in LabeledRecords_original])
# print top 10 most common names that published papers in current dataset
print(Record_NameCounter.most_common(10))
# Out:
# [('wei wang', 9014), ('y wang', 7355), ('m takahashi', 6323), ('y zhang', 6180), ('k yamamoto', 5728), ('h suzuki', 5419), ('k sato', 5375), ('yan wang', 5356), ('yan zhang', 5325), ('j zhang', 5317)]

# %%
# group same name records together
# first extract all names
authorNames = Record_NameCounter.keys()
print(len(authorNames))
print(list(authorNames)[:5])
# Out:
# 336916
# ['jonathan m read', 'j m read', 'jonathan read', 'jenny read', 'jenny c a read']

# %%
#
