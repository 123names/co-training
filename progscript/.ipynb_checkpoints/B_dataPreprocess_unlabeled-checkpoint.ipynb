# %%
# load the file
import sys
import io
import os

fileDir = "../Data/canopies/"
listfiles = os.listdir(fileDir)
allPapersInFile_original = []

for file in listfiles:
    if not file.startswith('.'):
        with open(fileDir+file, 'r', encoding = 'utf8') as f:
            for line in f:
                read_data = line.split("\t")
                # get ride of bad formated lines
                if(len(read_data)==13):
                    paper_detail = {"paperID": read_data[0], "authorID":read_data[1],
                                    "author_position":read_data[2], "total_author": read_data[3],
                                    "author_name": read_data[4], "co_authors": read_data[5], 
                                    "department": read_data[6], "vendor": read_data[7], 
                                    "mesh": read_data[8], "keywords": read_data[9], 
                                    "publish_year": read_data[10], "citation graph": read_data[11]}
                    allPapersInFile_original.append(paper_detail)
        f.close()
print("Total records:",len(allPapersInFile_original), "records")
# Out:
# Total records: 4163770 records

# %%
# extract all papers that are unlabeled (authorID==-1)
UnlabeledPapersInFile = []
for paper in allPapersInFile_original:
    if paper["authorID"]==str(-1):
        UnlabeledPapersInFile.append(paper)
print("Total unlabeled records: ",len(UnlabeledPapersInFile))
# Out:
# Total unlabeled records:  4023504

# %%
# Process one, get unlabeled paper records that have full last name
print(UnlabeledPapersInFile[:3])
authorNames = set([records["author_name"] for records in UnlabeledPapersInFile])
print(len(authorNames))
noLastNameList = []
counter = 0
for author in authorNames:
    name_part = author.split(" ")
    # if only have last name, print it out for check
    if(len(name_part)<2):
        print(author)
    if(len(name_part[-1])>=2):
        counter+=1
        # check if first name is complete or not
#         if(len(name_part[0])<2):
#             print(name_part)
    # if last name length less than 2, append to list
    else:
        noLastNameList.append(author)
        print(author)
print("Number of authors have last name: ",counter)

unlabeledRecords_processed1 = []
for record in UnlabeledPapersInFile:
    if(record["author_name"] not in noLastNameList):
        unlabeledRecords_processed1.append(record)
print("Number of records have full last name: ",len(unlabeledRecords_processed1))
# Out:
# [{'paperID': '73576', 'authorID': '-1', 'author_position': '2', 'total_author': '4', 'author_name': 'j read', 'co_authors': 'bird robertson currie', 'department': '', 'vendor': '3611', 'mesh': 'Burkitt Lymphoma$$Cell Count$$Cell Line$$Cell Survival$$Dexamethasone$$Glucocorticoids$$Kinetics$$Leukemia$$Leukemia, Lymphoid$$Leukemia, Myeloid, Acute$$Methylprednisolone$$Time Factors', 'keywords': '', 'publish_year': '1977', 'citation graph': '10.1016/0026-0495(72)90048-0$$10.1038/newbio232216a0$$10.1038/newbio237020a0$$10.1016/0026-0495(74)90113-9$$10.1016/0014-4827(76)90617-0'}, {'paperID': '320686', 'authorID': '-1', 'author_position': '0', 'total_author': '1', 'author_name': 'j m read', 'co_authors': '', 'department': '', 'vendor': '6067', 'mesh': 'Animals$$Femoral Artery$$Femoral Vein$$Microsurgery$$Rats$$Skin Transplantation$$Transplantation, Autologous', 'keywords': '', 'publish_year': '1977', 'citation graph': ''}, {'paperID': '418969', 'authorID': '-1', 'author_position': '0', 'total_author': '2', 'author_name': 'j a read', 'co_authors': 'miller', 'department': '', 'vendor': '4701', 'mesh': 'Anesthesia, Local$$Anesthesia, Obstetrical$$Bupivacaine$$Female$$Fetal Monitoring$$Fetus$$Humans$$Labor, Obstetric$$Pregnancy$$Uterine Contraction', 'keywords': '', 'publish_year': '1979', 'citation graph': ''}]
# 333813
# zheng
# lim
# terry
# kwon
# morris
# ribeiro
# matos
# saha
# kobayashi
# nielsen
# larsen
# webb
# swamy
# ramos
# vogel
# allen
# patel
# ferrara
# chang
# jacobson
# norman
# john
# jones
# moreira
# campos
# fontana
# parsons
# nelson
# jain
# davies
# keller
# barker
# berg
# fuchs
# white
# mansour
# silva
# qiu
# ismail
# reddy
# agrawal
# park
# oliveira
# fujita
# franco
# tavares
# bennett
# vaughan
# fabbri
# aguilar
# schneider
# kang
# bose
# hara
# ho
# unknown wellcome trust case control consortium 2
# fan
# sinha
# sadeghi
# coelho
# qin
# tsai
# ferrari
# blanco
# mitchell
# reid
# popov
# mayer
# wallace
# tan
# kato
# longo
# chiang
# lloyd
# amin
# hughes
# anderson
# castro
# mishra
# hassan
# yun
# cunha
# king
# jin
# hui
# sousa
# svensson
# nunes
# fonseca
# rubin
# gordon
# pearson
# gutierrez
# morgan
# cruz
# feng
# chow
# yao
# wong
# yan
# cao
# sinclair
# ding
# koh
# srivastava
# zhu
# kar
# robinson
# krause
# gross
# wood
# mora
# costa
# lau
# abe
# hsu
# singh
# su
# richard
# cho
# fisher
# figueroa
# reilly
# brito
# lai
# jo
# he
# graham
# weiner
# nomura
# richardson
# zhong
# carter
# arthur
# schwartz
# coleman
# taylor
# hsieh
# cox
# ren
# green
# dean
# antunes
# may
# ahn
# vogt
# nagy
# miranda
# murphy
# rogers
# sirajuddin
# lopez
# crespo
# liu
# pan
# herrero
# gandhi
# yuan
# ansari
# stewart
# porter
# chien
# huber
# guan
# shao
# hansen
# tran
# read
# yue
# tseng
# luo
# hill
# unknown samantha s
# oh
# pedersen
# gupta
# machado
# liao
# mori
# ricci
# vlachos
# williams
# thompson
# bhattacharyya
# davis
# berry
# sherman
# levy
# yamamoto
# bhushan
# saraf
# teixeira
# scott
# johansson
# delgado
# watson
# klein
# palma
# li
# henderson
# chapman
# madsen
# cheung
# moore
# lin
# hasan
# jha
# kumar
# huang
# muller
# baranov
# wagner
# jung
# vega
# henry
# zhou
# chin
# myers
# fischer
# khan
# hou
# day
# cui
# othman
# conte
# wolf
# han
# fernandez
# albert
# chen
# zeng
# evans
# chou
# soares
# ghosh
# mills
# lopes
# shah
# richter
# gao
# ko
# melo
# brennan
# larsson
# sharma
# jeong
# murakami
# unknown lakshman k
# sampaio
# roy
# hossain
# esposito
# howell
# black
# you
# wen
# peters
# shen
# johnston
# little
# cheng
# seo
# ruiz
# vitale
# wilson
# nilsson
# o'connor
# young
# soto
# cardoso
# xue
# brooks
# acosta
# marshall
# lam
# shenoy
# correia
# duarte
# fang
# uddin
# zhang
# simpson
# collins
# chan
# adams
# cai
# kim
# shim
# matthews
# schultz
# ferguson
# lewis
# lima
# barrett
# mosquera
# ibrahim
# barbosa
# ng
# stevens
# jensen
# pereira
# cameron
# inoue
# hartmann
# schmitt
# marques
# liqunyu
# mcdonald
# schindler
# goldman
# burton
# barnett
# song
# jacobs
# d'souza
# ferretti
# maia
# arora
# dias
# andersson
# field
# shaw
# baker
# howard
# iqbal
# chong
# wei
# wright
# zhao
# choi
# choudhury
# ma
# bates
# alexander
# yang
# james
# wheeler
# rocha
# cooper
# christensen
# branco
# schmidt
# fleming
# conde
# rasmussen
# gonzalez
# martinez
# lu
# elliott
# bae
# hosseini
# magnusson
# takahashi
# murray
# rizzo
# logan
# freitas
# schroeder
# hussain
# bauer
# eklund
# gomes
# marino
# ellis
# bianchi
# sandberg
# rosa
# weber
# das
# pandey
# o'brien
# morales
# biswas
# gil
# fu
# fox
# jackson
# alves
# esteves
# kong
# giuliani
# vieira
# shin
# krishnan
# reynolds
# foster
# yin
# saito
# jiang
# suzuki
# yamaguchi
# pimentel
# ito
# ray
# wang
# ford
# rodrigues
# ryan
# mccarthy
# brown
# rodriguez
# cuevas
# sullivan
# mukherjee
# ali
# bell
# guerrero
# mm
# ferreira
# andrews
# shi
# sahu
# monteiro
# barreto
# kelly
# doyle
# ross
# ward
# carr
# schmid
# ye
# torres
# vincent
# francis
# russo
# walsh
# patil
# martins
# santoro
# rao
# ahmed
# liang
# watanabe
# carvalho
# harris
# yu
# tang
# persson
# andersen
# qian
# almeida
# hall
# sato
# shimizu
# boyle
# jia
# stevenson
# chao
# nieto
# cattaneo
# phillips
# goh
# clark
# sanders
# barros
# russell
# mohan
# zou
# mukhopadhyay
# becker
# stanley
# thomsen
# yi
# garcia
# lynch
# arango
# moon
# gu
# luz
# mahmoud
# hong
# george
# dong
# xiao
# dai
# sohn
# lee
# peng
# schubert
# mitra
# paredes
# meyer
# tanaka
# camacho
# lang
# xie
# nguyen
# cohen
# mohanty
# roberts
# moraes
# sengupta
# simon
# yoshida
# tian
# lucas
# batista
# west
# hwang
# andrade
# petersen
# moreno
# walker
# martin
# islam
# weaver
# nakajima
# mckay
# warner
# xu
# radhakrishnan
# santos
# macdonald
# braun
# manning
# ortega
# kuo
# yoo
# goel
# unknown chavi core b
# shimada
# jacobsen
# guidi
# pinto
# miller
# hu
# paul
# wu
# lombardi
# johnson
# amaral
# smith
# mcevoy
# romero
# yoon
# grant
# fernandes
# rossi
# regan
# goodman
# parker
# gray
# woo
# thomas
# turner
# lowe
# Number of authors have last name:  333809
# Number of records have full last name:  4023500

# %%
# process two
