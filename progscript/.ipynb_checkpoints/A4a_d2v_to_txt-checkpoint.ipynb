# %%
import gensim
import logging
import os
import numpy as np
from matplotlib import pyplot

Dataset = "pubmed"

# pv_dm, pv_dbow
select_model = "pv_dbow"

# load existing model
print("Loading model ........")
model_path = ""
# 140k, 3m
training_size = "3m"

#"models/"+Dataset+"/pv_dm/text_sample="+training_size+"_mc=3/Doc2Vec(dmm,d100,n5,w5,mc3,s0.001,t24)"
#"models/"+Dataset+"/pv_dbow/text_sample="+training_size+"_mc=3/Doc2Vec(dbow,d100,n5,mc3,s0.001,t24)"

if select_model == "pv_dm":
    model_path = "models/"+Dataset+"/pv_dm/text_sample="+training_size+"/Doc2Vec(dmm,d100,n5,w5,mc2,s0.001,t24)"
elif select_model == "pv_dbow":
    model_path = "models/"+Dataset+"/pv_dbow/text_sample="+training_size+"/Doc2Vec(dbow,d100,n5,mc2,s0.001,t24)"
print(model_path)
model = gensim.models.Doc2Vec.load(model_path)
print("Done")
# Out:
# Loading model ........
# models/pubmed/pv_dbow/textual_sample=3m/Doc2Vec(dbow,d100,n5,mc2,s0.001,t24)
# Done

# %%
text_emb = []
allPaperTags = model.docvecs.offset2doctag
for pid in allPaperTags:
    vectorRepresentation = model.docvecs[pid].tolist()
    vectorRepresentation = [float(i) for i in vectorRepresentation]
    text_emb.append([pid]+vectorRepresentation)
print(text_emb[0])
# Out:
# ['27406695', 0.34846335649490356, -0.4063728153705597, 0.14911754429340363, 0.2694016396999359, -0.0011969383340328932, -0.41807907819747925, -0.22732897102832794, 0.08543888479471207, -0.1657133251428604, 0.15592728555202484, -0.01476085465401411, -0.6753616333007812, -0.06952470541000366, 0.03790159896016121, 0.2733183205127716, 0.48174816370010376, 0.03490469977259636, -0.011488683521747589, -0.26567065715789795, -0.5354878306388855, -0.4589062035083771, 0.383804053068161, 0.19680388271808624, -0.09530800580978394, -0.08991071581840515, 0.27292600274086, -0.0787607878446579, -0.06106853485107422, 0.9395225048065186, -0.8723549842834473, 0.5478936433792114, -0.10697297006845474, -0.26720350980758667, -0.7654099464416504, -0.06958475708961487, -0.1523587554693222, 0.5648553967475891, 0.12429364025592804, 0.0969856008887291, 0.16671034693717957, 0.4046115577220917, -0.9068968296051025, 0.1671781837940216, -0.014504977501928806, 0.11460666358470917, -0.0005704378127120435, -0.28016042709350586, -0.4944598078727722, -0.30865538120269775, 0.6205205321311951, -0.6276470422744751, 0.47976940870285034, 0.6947430372238159, 0.2951805591583252, 0.10790794342756271, 0.3923397958278656, 0.35180026292800903, 0.10718654841184616, -0.658581018447876, 0.4843939244747162, -0.08555031567811966, 0.08797122538089752, -0.047594666481018066, 0.5292065143585205, -0.04947385936975479, 0.0028962106443941593, 0.0061204684898257256, 0.0652380883693695, -0.10203814506530762, 0.21152761578559875, -0.45628678798675537, -0.2514275014400482, 0.421078085899353, -0.1369764506816864, 0.10374551266431808, -0.08422161638736725, 0.18142688274383545, 0.2536965012550354, -0.2171819657087326, -0.34959957003593445, 0.43451374769210815, -0.2170196771621704, 0.6318392753601074, -0.23760072886943817, 0.4052327573299408, -0.1448916792869568, -0.06540049612522125, 0.38191452622413635, 0.08767212182283401, 0.057519398629665375, -0.06292397528886795, -0.10540176928043365, 0.196427583694458, 0.11976969242095947, 0.29380902647972107, 1.1206015348434448, 0.33491015434265137, 0.001122511806897819, 0.42933180928230286, -0.1005566269159317]

# %%
# size of vocab
# "mc = 2": 605828
# "mc = 3": 475587
print(len(model.wv.vocab))
# print number of doc vec
print(len(model.docvecs))
# print list of all tags
allPaperTags = model.docvecs.offset2doctag
print(allPaperTags[:100])
# dimension of the doc vector
print(len(model.docvecs[0]))
# example of one doc vectors
print(model.docvecs['8077'])
test = model.docvecs['8077'].tolist()
test = [format(i, '.8f') for i in test]
print(test)
print(type(test))
# Out:
# 475587
# 3151504
# ['27406695', '26876744', '26978780', '26794258', '26628514', '27990325', '26218599', '25467590', '25734701', '27471659', '25614793', '25091803', '25009062', '24789897', '24968312', '24780494', '23804621', '22687447', '22829765', '22718990', '21288945', '21829185', '22877143', '20029657', '21352752', '18319209', '17663715', '16765401', '15899007', '14512953', '12713743', '27269605', '27196696', '26587261', '24880153', '24874550', '24349416', '24071587', '23755355', '23743415', '23055504', '23144596', '22427696', '23482297', '22401898', '22617270', '21158884', '21876667', '21220559', '20377279', '20884592', '21047742', '20107071', '20955471', '20830303', '20421992', '19073795', '19757912', '17828262', '17209738', '16763042', '15471592', '15788521', '16097873', '14523074', '15333204', '12711706', '12867533', '12020451', '11911114', '22077989', '23330781', '23064335', '26970400', '26757311', '26963178', '26081981', '25497472', '26156083', '25495021', '25572791', '25004873', '24534123', '25064809', '24919446', '24215794', '23662697', '23117816', '23002095', '23916362', '23986724', '23672238', '22961289', '23769383', '21429977', '22461484', '22651678', '21741038', '22297585', '21945128']
# 100
# [-0.1465914  -0.16460477 -0.50664663 -0.17956261  0.21054362  0.26002276
#   0.15514752  0.1324489  -0.27113414  0.47227725  0.07357255 -0.0896453
#   0.3595001   0.37851566 -0.04907404  0.56523114 -0.60256726 -0.21556917
#  -0.09287039 -0.18874674  0.5988131  -0.32156968  0.39462098  0.35133442
#   0.08628392 -0.04479222  0.2545322   0.23234852 -0.10687385 -0.0070719
#  -0.11578006  0.06657255  0.19292782  0.09975667 -0.04673584  0.47342294
#   0.5050351  -0.13644342  0.3502031   0.2745226   0.4598683   0.7215768
#  -0.08654509 -0.3692203  -0.28984016  0.26503867 -0.14659104  0.19001262
#  -0.24055083  0.10608102 -0.21904105 -0.02745518 -0.27935785  0.67074525
#   0.57324684  0.16567072 -0.12955795 -0.7399192   0.20633785 -0.13949864
#   0.07348444 -0.45851952 -0.28298637  0.6500598  -0.16004808 -0.3363464
#   0.7148133  -0.08647151  0.6137856   0.84790415 -0.4087136   0.4306219
#   0.01380008  0.8169324   0.22439685 -0.32138148  0.39291272  0.7150641
#   0.03570956  0.02829047  0.04145329 -0.13109712  0.3515574  -0.21288362
#   0.19800952  0.07500107 -0.23002854  0.24881081 -0.33990535  0.12203706
#  -0.1882481   0.12419476 -0.0909391   0.5412976  -0.4378614   0.05272437
#   0.42604834 -0.6086051   0.2935113   0.69737893]
# ['-0.14659140', '-0.16460477', '-0.50664663', '-0.17956261', '0.21054362', '0.26002276', '0.15514752', '0.13244890', '-0.27113414', '0.47227725', '0.07357255', '-0.08964530', '0.35950011', '0.37851566', '-0.04907404', '0.56523114', '-0.60256726', '-0.21556917', '-0.09287039', '-0.18874674', '0.59881312', '-0.32156968', '0.39462098', '0.35133442', '0.08628392', '-0.04479222', '0.25453219', '0.23234852', '-0.10687385', '-0.00707190', '-0.11578006', '0.06657255', '0.19292782', '0.09975667', '-0.04673584', '0.47342294', '0.50503510', '-0.13644342', '0.35020310', '0.27452260', '0.45986831', '0.72157681', '-0.08654509', '-0.36922029', '-0.28984016', '0.26503867', '-0.14659104', '0.19001262', '-0.24055083', '0.10608102', '-0.21904105', '-0.02745518', '-0.27935785', '0.67074525', '0.57324684', '0.16567072', '-0.12955795', '-0.73991919', '0.20633785', '-0.13949864', '0.07348444', '-0.45851952', '-0.28298637', '0.65005982', '-0.16004808', '-0.33634639', '0.71481329', '-0.08647151', '0.61378562', '0.84790415', '-0.40871361', '0.43062189', '0.01380008', '0.81693238', '0.22439685', '-0.32138148', '0.39291272', '0.71506411', '0.03570956', '0.02829047', '0.04145329', '-0.13109712', '0.35155740', '-0.21288362', '0.19800952', '0.07500107', '-0.23002854', '0.24881081', '-0.33990535', '0.12203706', '-0.18824810', '0.12419476', '-0.09093910', '0.54129761', '-0.43786141', '0.05272437', '0.42604834', '-0.60860509', '0.29351130', '0.69737893']
# <class 'list'>

# %%
import unicodedata
import string
valid_filename_chars = "-_.,() %s%s" % (string.ascii_letters, string.digits)
char_limit = 255
def clean_filename(filename, whitelist=valid_filename_chars, replace=' '):
    # replace spaces
    for r in replace:
        filename = filename.replace(r,'_')
    
    # keep only valid ascii chars
    cleaned_filename = unicodedata.normalize('NFKD', filename).encode('ASCII', 'ignore').decode()
    
    # keep only whitelisted chars
    cleaned_filename = ''.join(c for c in cleaned_filename if c in whitelist)
    if len(cleaned_filename)>char_limit:
        print("Warning, filename truncated because it was over {}. Filenames may no longer be unique".format(char_limit))
    return cleaned_filename[:char_limit]

# %%
clean_filename(model.__str__())
# Out:
# 'Doc2Vec(dbow,d100,n5,mc2,s0.001,t24)'

# %%
# export the paper vector representation to txt file
newfileDir = "vectors/"+Dataset+"/"+select_model+"/text_sample="+training_size+"/"
if not os.path.exists(newfileDir):
    os.makedirs(newfileDir)
allPaperTags = model.docvecs.offset2doctag
newf = open(newfileDir+clean_filename(model.__str__())+".txt", "w",encoding='utf8')

for paper in allPaperTags:
    vectorRepresentation = model.docvecs[paper].tolist()
    vectorRepresentation = [format(i, '.8f') for i in vectorRepresentation]
    vectorRepresentation = ' '.join(vectorRepresentation)
    newf.write(paper+" "+vectorRepresentation+ "\n")
newf.close()
